# %%
import pandas as pd
profile = ['2026-03-25'
,
'정지민'
,
'2002-09-27'
,
'ISFP']
profile = pd.Series(profile)

# %%
profile
# Out:
# 0    2026-03-25
# 1           정지민
# 2    2002-09-27
# 3          ISFP
# dtype: str
